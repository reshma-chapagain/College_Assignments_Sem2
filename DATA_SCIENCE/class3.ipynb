# %%
import pandas as pd

# %%
#read Csv file as Data

# %%
df = pd.read_csv("pokemon.csv")

# %%
df.head(2)
# Out:
#    id       name  type1   type2  hp  attack  defense  speed
# 0   1  Bulbasaur  Grass  Poison  45      49       49     45
# 1   2    Ivysaur  Grass  Poison  60      62       63     60

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       9 non-null      int64
#  1   name     9 non-null      str
#  2   type1    9 non-null      str
#  3   type2    4 non-null      str
#  4   hp       9 non-null      int64
#  5   attack   9 non-null      int64
#  6   defense  9 non-null      int64
#  7   speed    9 non-null      int64
# dtypes: int64(5), str(3)
# memory usage: 708.0 bytes

# %%
new_df = df[df['hp']>69]

# %%
new_df.shape
# Out:
# (3, 8)

# %%
df [(df['hp']>=70) & (df['attack']>=80)]
# Out:
#    id       name  type1   type2  hp  attack  defense  speed
# 2   3   Venusaur  Grass  Poison  80      82       83     80
# 5   6  Charizard   Fire  Flying  78      84       78    100
# 8   9  Blastoise  Water     NaN  79      83      100     78

# %%
new_df1 = df [(df['hp']>=70) | (df['attack']>=80)]

# %%
new_df1.head()
# Out:
#    id       name  type1   type2  hp  attack  defense  speed
# 2   3   Venusaur  Grass  Poison  80      82       83     80
# 5   6  Charizard   Fire  Flying  78      84       78    100
# 8   9  Blastoise  Water     NaN  79      83      100     78

# %%
new_df2 =df [(df['speed']>=80) & (df['attack']<=100)]

# %%
new_df2.head()
# Out:
#    id        name  type1   type2  hp  attack  defense  speed
# 2   3    Venusaur  Grass  Poison  80      82       83     80
# 4   5  Charmeleon   Fire     NaN  58      64       58     80
# 5   6   Charizard   Fire  Flying  78      84       78    100

# %%
#filter columns

# %%
df.columns
# Out:
# Index(['id', 'name', 'type1', 'type2', 'hp', 'attack', 'defense', 'speed'], dtype='str')

# %%
df [['name', 'type1' , 'hp']]
# Out:
#          name  type1  hp
# 0   Bulbasaur  Grass  45
# 1     Ivysaur  Grass  60
# 2    Venusaur  Grass  80
# 3  Charmander   Fire  39
# 4  Charmeleon   Fire  58
# 5   Charizard   Fire  78
# 6    Squirtle  Water  44
# 7   Wartortle  Water  59
# 8   Blastoise  Water  79

# %%
df [['name', 'type1', 'attack', 'speed']]
# Out:
#          name  type1  attack  speed
# 0   Bulbasaur  Grass      49     45
# 1     Ivysaur  Grass      62     60
# 2    Venusaur  Grass      82     80
# 3  Charmander   Fire      52     65
# 4  Charmeleon   Fire      64     80
# 5   Charizard   Fire      84    100
# 6    Squirtle  Water      48     43
# 7   Wartortle  Water      63     58
# 8   Blastoise  Water      83     78

# %%
df[(df['attack']>80) & (df['speed']<=100)] [['name', 'type1', 'attack','speed']]
# Out:
#         name  type1  attack  speed
# 2   Venusaur  Grass      82     80
# 5  Charizard   Fire      84    100
# 8  Blastoise  Water      83     78

# %%
#exact value - loc iloc

# %%
df.loc[0:3,"name" : "defense"]
# Out:
#          name  type1   type2  hp  attack  defense
# 0   Bulbasaur  Grass  Poison  45      49       49
# 1     Ivysaur  Grass  Poison  60      62       63
# 2    Venusaur  Grass  Poison  80      82       83
# 3  Charmander   Fire     NaN  39      52       43

# %%
df.loc[0:3,"type2" :]
# Out:
#     type2  hp  attack  defense  speed
# 0  Poison  45      49       49     45
# 1  Poison  60      62       63     60
# 2  Poison  80      82       83     80
# 3     NaN  39      52       43     65

# %%
df.loc[0:3,["attack","type1", "name"]]
# Out:
#    attack  type1        name
# 0      49  Grass   Bulbasaur
# 1      62  Grass     Ivysaur
# 2      82  Grass    Venusaur
# 3      52   Fire  Charmander

# %%
df.loc[4, 'name'] = 'newname'

# %%
df.head()
# Out:
#    id        name  type1   type2  hp  attack  defense  speed
# 0   1   Bulbasaur  Grass  Poison  45      49       49     45
# 1   2     Ivysaur  Grass  Poison  60      62       63     60
# 2   3    Venusaur  Grass  Poison  80      82       83     80
# 3   4  Charmander   Fire     NaN  39      52       43     65
# 4   5     newname   Fire     NaN  58      64       58     80

# %%
df.iloc[0:5, 0:3]
# Out:
#    id        name  type1
# 0   1   Bulbasaur  Grass
# 1   2     Ivysaur  Grass
# 2   3    Venusaur  Grass
# 3   4  Charmander   Fire
# 4   5     newname   Fire

# %%
df.loc[0:5,]
# Out:
#    id        name  type1   type2  hp  attack  defense  speed
# 0   1   Bulbasaur  Grass  Poison  45      49       49     45
# 1   2     Ivysaur  Grass  Poison  60      62       63     60
# 2   3    Venusaur  Grass  Poison  80      82       83     80
# 3   4  Charmander   Fire     NaN  39      52       43     65
# 4   5     newname   Fire     NaN  58      64       58     80
# 5   6   Charizard   Fire  Flying  78      84       78    100

# %%
df['type1'].value_counts()
# Out:
# type1
# Grass    3
# Fire     3
# Water    3
# Name: count, dtype: int64

# %%
df['type1'].unique
# Out:
# <bound method Series.unique of 0    Grass
# 1    Grass
# 2    Grass
# 3     Fire
# 4     Fire
# 5     Fire
# 6    Water
# 7    Water
# 8    Water
# Name: type1, dtype: str>

# %%
df['type2'].value_counts()
# Out:
# type2
# Poison    3
# Flying    1
# Name: count, dtype: int64
