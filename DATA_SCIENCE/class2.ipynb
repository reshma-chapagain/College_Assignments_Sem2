# %%
import os
print(os.getcwd())
# Out:
# /home/reshma/Documents/College_Assignments_Sem2/DATA_SCIENCE

# %%
df = pd.read_csv("pokemon.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("pokemon.csv")
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    id        name  type1   type2  hp  attack  defense  speed
# 0   1   Bulbasaur  Grass  Poison  45      49       49     45
# 1   2     Ivysaur  Grass  Poison  60      62       63     60
# 2   3    Venusaur  Grass  Poison  80      82       83     80
# 3   4  Charmander   Fire     NaN  39      52       43     65
# 4   5  Charmeleon   Fire     NaN  58      64       58     80

# %%
df['type1']=='Grass'
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: type1, dtype: bool

# %%
df['type1']=='Fire'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# Name: type1, dtype: bool

# %%
df_grass = df[df['type1']=='Grass']

# %%
df_grass.shape #row and column
# Out:
# (3, 8)
